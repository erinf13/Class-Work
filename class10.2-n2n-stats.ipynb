# %%
import pandas as pd
import scipy.stats as stats

# check correlation between shots/goals and passes



url = "https://raw.githubusercontent.com/nkmwicz/worldcup2018data/refs/heads/main/cleaned_events_world_cup2018.csv"
df = pd.read_csv(url)
df.head()
# Out:
#    eventId subEventName                      tags  \
# 0        8  Simple pass              ['Accurate']
# 1        8    High pass              ['Accurate']
# 2        1     Air duel       ['Won', 'Accurate']
# 3        1     Air duel  ['Lost', 'Not accurate']
# 4        8  Simple pass              ['Accurate']
#
#                       playerId                       matchId eventName  \
# 0  Mohammad Ibrahim Al Sahlawi  Russia - Saudi Arabia, 5 - 0      Pass
# 1       Abdullah Ibrahim Otayf  Russia - Saudi Arabia, 5 - 0      Pass
# 2                 Ilya Kutepov  Russia - Saudi Arabia, 5 - 0      Duel
# 3    Yasir Gharsan Al Shahrani  Russia - Saudi Arabia, 5 - 0      Duel
# 4     Salman Mohammed Al Faraj  Russia - Saudi Arabia, 5 - 0      Pass
#
#          teamId matchPeriod  eventSec   subEventId         id  x1  y1    x2  \
# 0  Saudi Arabia          1H  1.656214  Simple pass  258612104  50  50  35.0
# 1  Saudi Arabia          1H  4.487814    High pass  258612106  35  53  75.0
# 2        Russia          1H  5.937411     Air duel  258612077  25  81  37.0
# 3  Saudi Arabia          1H  6.406961     Air duel  258612112  75  19  63.0
# 4  Saudi Arabia          1H  8.562167  Simple pass  258612110  63  17  71.0
#
#      y2
# 0  53.0
# 1  19.0
# 2  83.0
# 3  17.0
# 4  15.0

# %%
from functions.eda import eda
eda(df)
# Out:
# =====DF Shape: (101759, 15)=====
# ***Numeric Columns***
# eventId
#
# 	Num NA: 0
# 	% NA: 0.0%
# 	Min: 1
# 	Max: 10
# 	Range: 9
# 	25%: 1.0
# 	75%: 8.0
# 	St. Dev.: 3.115089378683579
# 	Num unique: 9
# eventSec
#
# 	Num NA: 0
# 	% NA: 0.0%
# 	Min: 0.122552999999982
# 	Max: 3258.366837
# 	Range: 3258.244284
# 	25%: 643.4694855
# 	75%: 2115.7787175000003
# 	St. Dev.: 850.98050790337
# 	Num unique: 100135
# id
#
# 	Num NA: 0
# 	% NA: 0.0%
# 	Min: 258612077
# 	Max: 280217520
# 	Range: 21605443
# 	25%: 259394664.5
# 	75%: 261094853.0
# 	St. Dev.: 4062609.8346007834
# 	Num unique: 101759
# x1
#
# 	Num NA: 0
# 	% NA: 0.0%
# 	Min: 0
# 	Max: 100
# 	Range: 100
# 	25%: 31.0
# 	75%: 68.0
# 	St. Dev.: 24.560053845410334
# 	Num unique: 101
# y1
#
# 	Num NA: 0
# 	% NA: 0.0%
# 	Min: 0
# 	Max: 101
# 	Range: 101
# 	25%: 23.0
# 	75%: 76.0
# 	St. Dev.: 30.01208708215375
# 	Num unique: 102
# x2
#
# 	Num NA: 4
# 	% NA: 0.003930856238760208%
# 	Min: 0.0
# 	Max: 100.0
# 	Range: 100.0
# 	25%: 33.0
# 	75%: 71.0
# 	St. Dev.: 24.962312126892407
# 	Num unique: 101
# y2
#
# 	Num NA: 4
# 	% NA: 0.003930856238760208%
# 	Min: 0.0
# 	Max: 101.0
# 	Range: 101.0
# 	25%: 23.0
# 	75%: 76.0
# 	St. Dev.: 30.356833722819964
# 	Num unique: 102
#
#
# ***CATEGORICAL COLS***
# subEventName
# 	Num NA: 172
# 	% NA: 0.16902681826668894%
# 	Num Uniques: 33
# tags
# 	Num NA: 0
# 	% NA: 0.0%
# 	Num Uniques: 490
# playerId
# 	Num NA: 0
# 	% NA: 0.0%
# 	Num Uniques: 602
# matchId
# 	Num NA: 0
# 	% NA: 0.0%
# 	Num Uniques: 64
# eventName
# 	Num NA: 0
# 	% NA: 0.0%
# 	Num Uniques: 9
# teamId
# 	Num NA: 0
# 	% NA: 0.0%
# 	Num Uniques: 32
# matchPeriod
# 	Num NA: 0
# 	% NA: 0.0%
# 	Num Uniques: 5
# Unique Vals: ['1H' '2H' 'E1' 'E2' 'P']
# subEventId
# 	Num NA: 172
# 	% NA: 0.16902681826668894%
# 	Num Uniques: 33

# %%
# find all shots
# find all goals
# find all passes

events = df["eventName"].unique()
events
# Out:
# array(['Pass', 'Duel', 'Free Kick', 'Foul', 'Others on the ball', 'Shot',
#        'Save attempt', 'Offside', 'Goalkeeper leaving line'], dtype=object)

# %%
df["pass"] = (df["eventName"] == "Pass").astype(int)
df["pass"].head()
# Out:
# 0    1
# 1    1
# 2    0
# 3    0
# 4    1
# Name: pass, dtype: int64

# %%
df["shot"] = (df["eventName"] == "Shot").astype(int)
df["shot"].head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: shot, dtype: int64

# %%
df["subEventName"].unique()
# Out:
# array(['Simple pass', 'High pass', 'Air duel', 'Ground attacking duel',
#        'Ground defending duel', 'Throw in', 'Foul', 'Free Kick',
#        'Clearance', 'Touch', 'Ground loose ball duel', 'Corner',
#        'Head pass', 'Launch', 'Acceleration', 'Shot', 'Smart pass',
#        'Cross', 'Reflexes', nan, 'Hand pass', 'Goal kick',
#        'Free kick cross', 'Hand foul', 'Save attempt', 'Free kick shot',
#        'Goalkeeper leaving line', 'Penalty', 'Late card foul',
#        'Violent Foul', 'Protest', 'Out of game foul', 'Time lost foul',
#        'Simulation'], dtype=object)

# %%
import ast
df["tags"] = df["tags"].apply(ast.literal_eval)

# %%
unique_tags = list(set([tag for taglist in df["tags"] for tag in taglist]))
unique_tags.sort()
unique_tags
# Out:
# ['Accurate',
#  'Anticipated',
#  'Anticipation',
#  'Assist',
#  'Blocked',
#  'Counter attack',
#  'Dangerous ball lost',
#  'Direct',
#  'Fairplay',
#  'Feint',
#  'Free space left',
#  'Free space right',
#  'Goal',
#  'Head/body',
#  'High',
#  'Indirect',
#  'Interception',
#  'Key pass',
#  'Left foot',
#  'Lost',
#  'Missed ball',
#  'Neutral',
#  'Not accurate',
#  'Opportunity',
#  'Own goal',
#  'Position: Goal center',
#  'Position: Goal center left',
#  'Position: Goal center right',
#  'Position: Goal high center',
#  'Position: Goal high left',
#  'Position: Goal high right',
#  'Position: Goal low center',
#  'Position: Goal low left',
#  'Position: Goal low right',
#  'Position: Out center left',
#  'Position: Out center right',
#  'Position: Out high center',
#  'Position: Out high left',
#  'Position: Out high right',
#  'Position: Out low left',
#  'Position: Out low right',
#  'Position: Post center left',
#  'Position: Post center right',
#  'Position: Post high center',
#  'Position: Post high left',
#  'Position: Post high right',
#  'Position: Post low left',
#  'Position: Post low right',
#  'Red card',
#  'Right foot',
#  'Second yellow card',
#  'Sliding tackle',
#  'Take on left',
#  'Take on right',
#  'Through',
#  'Won',
#  'Yellow card']

# %%
df["goal"] = (
    (df["eventName"] == "Shot") & 
    (df["tags"].apply(lambda taglist: "Goal" in taglist))
    ).astype(int)

# %%
# another way to do this

# df["goal"] = df.apply(lambda row: (row["eventName"] =="Shot") and ("Goal" in row["tags"]) , axis=1).astype(int)

# %%
df["matchId"].nunique()
# Out:
# 64

# %%
from typing import List
def group_data(columns: List[str]):
    grp = df.groupby(columns).agg(
        pass_count = ("pass", "sum"),
        shot_count = ("shot", "sum"),
        goal_count = ("goal", "sum"),
        matches_count = ("matchId", "nunique"),
    ).reset_index()
    return grp

# %% [markdown]
# ## By MatchID

# %%
m_grp = group_data(["matchId"])
r, p = stats.pearsonr(m_grp["pass_count"], m_grp["shot_count"])
r2 = r**2
print(f"pass-shots: matchID: r={r:.4f}, p={p:.4f}, r2={r2:.4f}")
# Out:
# pass-shots: matchID: r=0.1996, p=0.1138, r2=0.0398

# %% [markdown]
# ## By TeamID

# %%
m_grp = group_data(["teamId"])
r, p = stats.pearsonr(m_grp["pass_count"], m_grp["shot_count"])
r2 = r**2
print(f"pass-shots: teamID: r={r:.4f}, p={p:.4f}, r2={r2:.4f}")

r, p = stats.pearsonr(m_grp["pass_count"], m_grp["goal_count"])
r2 = r**2
print(f"pass-goals: teamID: r={r:.4f}, p={p:.4f}, r2={r2:.4f}")
# Out:
# pass-shots: teamID: r=0.8932, p=0.0000, r2=0.7979
# pass-goals: teamID: r=0.8541, p=0.0000, r2=0.7295

# %% [markdown]
# ## By TeamID Normalized

# %%
m_grp = group_data(["teamId"])

m_grp["pass_norm"] = m_grp["pass_count"] / m_grp["matches_count"]
m_grp["shots_norm"] = m_grp["shot_count"] / m_grp["matches_count"]
m_grp["goals_norm"] = m_grp["goal_count"] / m_grp["matches_count"]

r, p = stats.pearsonr(m_grp["pass_norm"], m_grp["shots_norm"])
r2 = r**2
print(f"pass-shots: teamID normalized: r={r:.4f}, p={p:.4f}, r2={r2:.4f}")

r, p = stats.pearsonr(m_grp["pass_norm"], m_grp["goals_norm"])
r2 = r**2
print(f"pass-goals: teamID normalized: r={r:.4f}, p={p:.4f}, r2={r2:.4f}")
# Out:
# pass-shots: teamID normalized: r=0.6667, p=0.0000, r2=0.4445
# pass-goals: teamID normalized: r=0.4271, p=0.0148, r2=0.1824

# %% [markdown]
# 44 % of movement in our shots is impacted by our passes (r2 = amount dependent impacts independent)

# %% [markdown]
# ## By MatchID and TeamID

# %%
m_grp = group_data(["matchId", "teamId"])
r, p = stats.pearsonr(m_grp["pass_count"], m_grp["shot_count"])
r2 = r**2
print(f"pass-shots: matchID & teamID : r={r:.4f}, p={p:.4f}, r2={r2:.4f}")

r, p = stats.pearsonr(m_grp["pass_count"], m_grp["goal_count"])
r2 = r**2
print(f"pass-goals: matchID & teamID : r={r:.4f}, p={p:.4f}, r2={r2:.4f}")
# Out:
# pass-shots: matchID & teamID : r=0.5642, p=0.0000, r2=0.3184
# pass-goals: matchID & teamID : r=0.1200, p=0.1772, r2=0.0144

# %% [markdown]
# ## Shots to Goals

# %%
m_grp = group_data(["teamId"])
r, p = stats.pearsonr(m_grp["shot_count"], m_grp["goal_count"])
r2 = r**2
print(f"shots-goals: teamID: r={r:.4f}, p={p:.4f}, r2={r2:.4f}")

m_grp = group_data(["matchId","teamId"])
r, p = stats.pearsonr(m_grp["shot_count"], m_grp["goal_count"])
r2 = r**2
print(f"shots-goals: matchID & teamID: r={r:.4f}, p={p:.4f}, r2={r2:.4f}")
# Out:
# shots-goals: teamID: r=0.8404, p=0.0000, r2=0.7063
# shots-goals: matchID & teamID: r=0.2107, p=0.0170, r2=0.0444
