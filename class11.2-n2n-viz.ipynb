# %%
import pandas as pd
import scipy.stats as stats
import ast
# check correlation between shots/goals and passes



url = "https://raw.githubusercontent.com/nkmwicz/worldcup2018data/refs/heads/main/cleaned_events_world_cup2018.csv"
df = pd.read_csv(url)

for col in df.columns:
    print(col)

df.head(1)
# Out:
# eventId
# subEventName
# tags
# playerId
# matchId
# eventName
# teamId
# matchPeriod
# eventSec
# subEventId
# id
# x1
# y1
# x2
# y2
#    eventId subEventName          tags                     playerId  \
# 0        8  Simple pass  ['Accurate']  Mohammad Ibrahim Al Sahlawi
#
#                         matchId eventName        teamId matchPeriod  eventSec  \
# 0  Russia - Saudi Arabia, 5 - 0      Pass  Saudi Arabia          1H  1.656214
#
#     subEventId         id  x1  y1    x2    y2
# 0  Simple pass  258612104  50  50  35.0  53.0

# %%
goals = df.loc[df["tags"].apply(lambda x: "Goal" in x)]

# %%
for row in goals.itertuples():
    if "Goal " in row.tags or " Goal" in row.tags:
        print(row.tags)
# Out:
# ['Goal', 'Head/body', 'Opportunity', 'Position: Goal low left', 'Accurate']
# ['Goal', 'Position: Goal low left', 'Not accurate']
# ['Goal', 'Left foot', 'Opportunity', 'Position: Goal high left', 'Accurate']
# ['Goal', 'Position: Goal high left', 'Not accurate']
# ['Head/body', 'Opportunity', 'Position: Goal high center', 'Accurate']
# ['Position: Goal high center', 'Accurate']
# ['Right foot', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Position: Goal low center', 'Accurate']
# ['Goal', 'Head/body', 'Opportunity', 'Position: Goal low right', 'Accurate']
# ['Goal', 'Position: Goal low right', 'Not accurate']
# ['Goal', 'Left foot', 'Opportunity', 'Position: Goal high right', 'Accurate']
# ['Goal', 'Position: Goal high right', 'Not accurate']
# ['Goal', 'Right foot', 'Direct', 'Opportunity', 'Position: Goal center right', 'Accurate']
# ['Goal', 'Position: Goal center right', 'Not accurate']
# ['Right foot', 'Opportunity', 'Position: Goal low left', 'Accurate']
# ['Position: Goal low left', 'Accurate']
# ['Right foot', 'Opportunity', 'Position: Goal low right', 'Accurate']
# ['Position: Goal low right', 'Accurate']
# ['Right foot', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Position: Goal low center', 'Accurate']
# ['Right foot', 'Opportunity', 'Position: Goal center', 'Accurate']
# ['Position: Goal center', 'Accurate']
# ['Counter attack', 'Right foot', 'Opportunity', 'Position: Goal center', 'Accurate']
# ['Position: Goal center', 'Accurate']
# ['Right foot', 'Opportunity', 'Position: Goal center', 'Accurate']
# ['Position: Goal center', 'Accurate']
# ['Goal', 'Head/body', 'Opportunity', 'Position: Goal center right', 'Accurate']
# ['Goal', 'Position: Goal center right', 'Not accurate']
# ['Head/body', 'Opportunity', 'Position: Goal center', 'Accurate']
# ['Position: Goal center', 'Accurate']
# ['Goal', 'Left foot', 'Opportunity', 'Position: Goal low right', 'Accurate']
# ['Goal', 'Position: Goal low right', 'Not accurate']
# ['Goal', 'Right foot', 'Opportunity', 'Position: Goal low right', 'Accurate']
# ['Goal', 'Position: Goal low right', 'Not accurate']
# ['Goal', 'Left foot', 'Position: Goal high center', 'Accurate']
# ['Goal', 'Position: Goal high center', 'Not accurate']
# ['Head/body', 'Opportunity', 'Position: Goal center', 'Accurate']
# ['Position: Goal center', 'Accurate']
# ['Right foot', 'Opportunity', 'Position: Goal center left', 'Accurate']
# ['Counter attack', 'Position: Goal center left', 'Accurate']
# ['Goal', 'Left foot', 'Opportunity', 'Position: Goal center right', 'Accurate']
# ['Goal', 'Position: Goal center right', 'Not accurate']
# ['Left foot', 'Opportunity', 'Position: Goal high center', 'Accurate']
# ['Position: Goal high center', 'Accurate']
# ['Right foot', 'Direct', 'Opportunity', 'Position: Goal low right', 'Accurate']
# ['Position: Goal low right', 'Accurate']
# ['Right foot', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Position: Goal low center', 'Accurate']
# ['Head/body', 'Opportunity', 'Position: Goal center right', 'Accurate']
# ['Position: Goal center right', 'Accurate']
# ['Right foot', 'Opportunity', 'Position: Goal low left', 'Accurate']
# ['Position: Goal low left', 'Accurate']
# ['Goal', 'Right foot', 'Direct', 'Opportunity', 'Position: Goal low right', 'Accurate']
# ['Goal', 'Position: Goal low right', 'Not accurate']
# ['Right foot', 'Opportunity', 'Position: Goal center', 'Accurate']
# ['Position: Goal center', 'Accurate']
# ['Counter attack', 'Right foot', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Position: Goal low center', 'Accurate']
# ['Left foot', 'Opportunity', 'Position: Goal high center', 'Accurate']
# ['Position: Goal high center', 'Accurate']
# ['Left foot', 'Opportunity', 'Position: Goal high right', 'Accurate']
# ['Position: Goal high right', 'Accurate']
# ['Head/body', 'Opportunity', 'Position: Goal center left', 'Accurate']
# ['Position: Goal center left', 'Accurate']
# ['Goal', 'Left foot', 'Opportunity', 'Position: Goal center left', 'Accurate']
# ['Goal', 'Position: Goal center left', 'Not accurate']
# ['Goal', 'Counter attack', 'Left foot', 'Opportunity', 'Position: Goal center', 'Accurate']
# ['Goal', 'Position: Goal center', 'Not accurate']
# ['Left foot', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Position: Goal low center', 'Accurate']
# ['Right foot', 'Position: Goal center left', 'Not accurate']
# ['Position: Goal center left', 'Accurate']
# ['Goal', 'Left foot', 'Position: Goal center left', 'Accurate']
# ['Goal', 'Position: Goal center left', 'Not accurate']
# ['Head/body', 'Opportunity', 'Position: Goal high center', 'Accurate']
# ['Position: Goal high center', 'Accurate']
# ['Head/body', 'Opportunity', 'Position: Goal center', 'Accurate']
# ['Position: Goal center', 'Accurate']
# ['Right foot', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Position: Goal low center', 'Accurate']
# ['Goal', 'Right foot', 'Opportunity', 'Position: Goal low left', 'Accurate']
# ['Goal', 'Position: Goal low left', 'Not accurate']
# ['Goal', 'Right foot', 'Position: Goal center right', 'Accurate']
# ['Goal', 'Position: Goal center right', 'Not accurate']
# ['Goal', 'Counter attack', 'Right foot', 'Opportunity', 'Position: Goal low left', 'Accurate']
# ['Goal', 'Position: Goal low left', 'Not accurate']
# ['Left foot', 'Opportunity', 'Position: Goal low right', 'Accurate']
# ['Position: Goal low right', 'Accurate']
# ['Goal', 'Left foot', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Goal', 'Position: Goal low center', 'Not accurate']
# ['Goal', 'Right foot', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Goal', 'Position: Goal low center', 'Not accurate']
# ['Goal', 'Right foot', 'Opportunity', 'Position: Goal low left', 'Accurate']
# ['Goal', 'Position: Goal low left', 'Not accurate']
# ['Left foot', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Position: Goal low center', 'Accurate']
# ['Goal', 'Right foot', 'Direct', 'Opportunity', 'Position: Goal high right', 'Accurate']
# ['Goal', 'Position: Goal high right', 'Not accurate']
# ['Left foot', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Position: Goal low center', 'Accurate']
# ['Right foot', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Position: Goal low center', 'Accurate']
# ['Counter attack', 'Right foot', 'Opportunity', 'Position: Goal low right', 'Accurate']
# ['Position: Goal low right', 'Accurate']
# ['Right foot', 'Opportunity', 'Position: Goal center right', 'Accurate']
# ['Position: Goal center right', 'Accurate']
# ['Left foot', 'Opportunity', 'Position: Goal low left', 'Accurate']
# ['Position: Goal low left', 'Accurate']
# ['Goal', 'Head/body', 'Opportunity', 'Position: Goal high right', 'Accurate']
# ['Goal', 'Position: Goal high right', 'Not accurate']
# ['Head/body', 'Opportunity', 'Position: Goal low left', 'Accurate']
# ['Position: Goal low left', 'Accurate']
# ['Right foot', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Position: Goal low center', 'Accurate']
# ['Right foot', 'Opportunity', 'Position: Goal center', 'Accurate']
# ['Position: Goal center', 'Accurate']
# ['Right foot', 'Opportunity', 'Position: Goal high center', 'Accurate']
# ['Position: Goal high center', 'Accurate']
# ['Head/body', 'Opportunity', 'Position: Goal center left', 'Accurate']
# ['Position: Goal center left', 'Accurate']
# ['Left foot', 'Direct', 'Opportunity', 'Position: Goal center', 'Accurate']
# ['Position: Goal center', 'Accurate']
# ['Right foot', 'Opportunity', 'Position: Goal high right', 'Accurate']
# ['Position: Goal high right', 'Accurate']
# ['Goal', 'Right foot', 'Opportunity', 'Position: Goal low left', 'Accurate']
# ['Goal', 'Position: Goal low left', 'Not accurate']
# ['Right foot', 'Opportunity', 'Position: Goal low left', 'Accurate']
# ['Position: Goal low left', 'Accurate']
# ['Head/body', 'Opportunity', 'Position: Goal center', 'Accurate']
# ['Position: Goal center', 'Accurate']
# ['Right foot', 'Opportunity', 'Position: Goal center', 'Accurate']
# ['Position: Goal center', 'Accurate']
# ['Goal', 'Right foot', 'Opportunity', 'Position: Goal high left', 'Accurate']
# ['Goal', 'Position: Goal high left', 'Not accurate']
# ['Right foot', 'Position: Goal center right', 'Not accurate']
# ['Position: Goal center right', 'Accurate']
# ['Goal', 'Right foot', 'Position: Goal high right', 'Accurate']
# ['Goal', 'Position: Goal high right', 'Not accurate']
# ['Goal', 'Left foot', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Goal', 'Position: Goal low center', 'Not accurate']
# ['Goal', 'Right foot', 'Opportunity', 'Position: Goal high left', 'Accurate']
# ['Goal', 'Position: Goal high left', 'Not accurate']
# ['Head/body', 'Opportunity', 'Position: Goal center right', 'Accurate']
# ['Position: Goal center right', 'Accurate']
# ['Left foot', 'Opportunity', 'Position: Goal center left', 'Accurate']
# ['Position: Goal center left', 'Accurate']
# ['Head/body', 'Opportunity', 'Position: Goal center right', 'Accurate']
# ['Position: Goal center right', 'Accurate']
# ['Goal', 'Head/body', 'Opportunity', 'Position: Goal high right', 'Accurate']
# ['Goal', 'Position: Goal high right', 'Not accurate']
# ['Goal', 'Right foot', 'Opportunity', 'Position: Goal center left', 'Accurate']
# ['Goal', 'Position: Goal center left', 'Not accurate']
# ['Right foot', 'Opportunity', 'Position: Goal center right', 'Accurate']
# ['Position: Goal center right', 'Accurate']
# ['Right foot', 'Direct', 'Opportunity', 'Position: Goal center', 'Accurate']
# ['Position: Goal center', 'Accurate']
# ['Right foot', 'Opportunity', 'Position: Goal low right', 'Accurate']
# ['Position: Goal low right', 'Accurate']
# ['Goal', 'Left foot', 'Position: Goal center right', 'Accurate']
# ['Goal', 'Position: Goal center right', 'Not accurate']
# ['Goal', 'Right foot', 'Position: Goal low right', 'Accurate']
# ['Goal', 'Position: Goal low right', 'Not accurate']
# ['Goal', 'Position: Goal high right', 'Not accurate']
# ['Left foot', 'Opportunity', 'Position: Goal center', 'Accurate']
# ['Position: Goal center', 'Accurate']
# ['Left foot', 'Opportunity', 'Position: Goal low left', 'Accurate']
# ['Position: Goal low left', 'Accurate']
# ['Right foot', 'Opportunity', 'Position: Goal center', 'Accurate']
# ['Position: Goal center', 'Accurate']
# ['Goal', 'Counter attack', 'Left foot', 'Opportunity', 'Position: Goal low left', 'Accurate']
# ['Goal', 'Position: Goal low left', 'Not accurate']
# ['Left foot', 'Opportunity', 'Position: Goal center', 'Accurate']
# ['Position: Goal center', 'Accurate']
# ['Head/body', 'Opportunity', 'Position: Goal center', 'Accurate']
# ['Position: Goal center', 'Accurate']
# ['Left foot', 'Opportunity', 'Position: Goal center right', 'Accurate']
# ['Position: Goal center right', 'Accurate']
# ['Right foot', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Position: Goal low center', 'Accurate']
# ['Left foot', 'Opportunity', 'Position: Goal center', 'Accurate']
# ['Position: Goal center', 'Accurate']
# ['Right foot', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Position: Goal low center', 'Accurate']
# ['Left foot', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Counter attack', 'Position: Goal low center', 'Accurate']
# ['Right foot', 'Opportunity', 'Position: Goal center', 'Accurate']
# ['Position: Goal center', 'Accurate']
# ['Goal', 'Right foot', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Goal', 'Position: Goal low center', 'Not accurate']
# ['Left foot', 'Opportunity', 'Position: Goal high center', 'Accurate']
# ['Position: Goal high center', 'Accurate']
# ['Right foot', 'Direct', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Position: Goal low center', 'Accurate']
# ['Goal', 'Left foot', 'Opportunity', 'Position: Goal high center', 'Accurate']
# ['Goal', 'Position: Goal high center', 'Not accurate']
# ['Left foot', 'Opportunity', 'Position: Goal center', 'Accurate']
# ['Position: Goal center', 'Accurate']
# ['Goal', 'Right foot', 'Position: Goal low right', 'Accurate']
# ['Goal', 'Position: Goal low right', 'Not accurate']
# ['Head/body', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Position: Goal low center', 'Accurate']
# ['Counter attack', 'Left foot', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Position: Goal low center', 'Accurate']
# ['Head/body', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Position: Goal low center', 'Accurate']
# ['Right foot', 'Opportunity', 'Position: Goal center left', 'Accurate']
# ['Position: Goal center left', 'Accurate']
# ['Left foot', 'Opportunity', 'Position: Goal high left', 'Accurate']
# ['Position: Goal high left', 'Accurate']
# ['Left foot', 'Opportunity', 'Position: Goal center', 'Accurate']
# ['Position: Goal center', 'Accurate']
# ['Left foot', 'Opportunity', 'Position: Goal high left', 'Accurate']
# ['Position: Goal high left', 'Accurate']
# ['Left foot', 'Opportunity', 'Position: Goal center', 'Accurate']
# ['Position: Goal center', 'Accurate']
# ['Left foot', 'Opportunity', 'Position: Goal low right', 'Accurate']
# ['Position: Goal low right', 'Accurate']
# ['Right foot', 'Direct', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Position: Goal low center', 'Accurate']
# ['Left foot', 'Opportunity', 'Position: Goal low left', 'Accurate']
# ['Position: Goal low left', 'Accurate']
# ['Goal', 'Right foot', 'Opportunity', 'Position: Goal low left', 'Accurate']
# ['Goal', 'Position: Goal low left', 'Not accurate']
# ['Head/body', 'Opportunity', 'Position: Goal center', 'Accurate']
# ['Position: Goal center', 'Accurate']
# ['Left foot', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Position: Goal low center', 'Accurate']
# ['Goal', 'Left foot', 'Opportunity', 'Position: Goal low right', 'Accurate']
# ['Goal', 'Position: Goal low right', 'Not accurate']
# ['Head/body', 'Opportunity', 'Position: Goal center left', 'Accurate']
# ['Position: Goal center left', 'Accurate']
# ['Left foot', 'Opportunity', 'Position: Goal center left', 'Accurate']
# ['Position: Goal center left', 'Accurate']
# ['Goal', 'Left foot', 'Opportunity', 'Position: Goal high left', 'Accurate']
# ['Goal', 'Position: Goal high left', 'Not accurate']
# ['Left foot', 'Opportunity', 'Position: Goal center left', 'Accurate']
# ['Position: Goal center left', 'Accurate']
# ['Goal', 'Right foot', 'Opportunity', 'Position: Goal center', 'Accurate']
# ['Goal', 'Position: Goal center', 'Not accurate']
# ['Head/body', 'Opportunity', 'Position: Goal center', 'Accurate']
# ['Position: Goal center', 'Accurate']
# ['Right foot', 'Opportunity', 'Position: Goal low right', 'Accurate']
# ['Position: Goal low right', 'Accurate']
# ['Left foot', 'Position: Goal center left', 'Not accurate']
# ['Position: Goal center left', 'Accurate']
# ['Counter attack', 'Right foot', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Position: Goal low center', 'Accurate']
# ['Right foot', 'Opportunity', 'Position: Goal center', 'Accurate']
# ['Position: Goal center', 'Accurate']
# ['Head/body', 'Opportunity', 'Position: Goal center', 'Accurate']
# ['Position: Goal center', 'Accurate']
# ['Goal', 'Right foot', 'Position: Goal low left', 'Accurate']
# ['Goal', 'Position: Goal low left', 'Not accurate']
# ['Head/body', 'Opportunity', 'Position: Goal high right', 'Accurate']
# ['Position: Goal high right', 'Accurate']
# ['Right foot', 'Opportunity', 'Position: Goal low left', 'Accurate']
# ['Position: Goal low left', 'Accurate']
# ['Left foot', 'Opportunity', 'Position: Goal low right', 'Accurate']
# ['Position: Goal low right', 'Accurate']
# ['Left foot', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Position: Goal low center', 'Accurate']
# ['Goal', 'Right foot', 'Opportunity', 'Position: Goal high center', 'Accurate']
# ['Goal', 'Position: Goal high center', 'Not accurate']
# ['Left foot', 'Opportunity', 'Position: Goal low left', 'Accurate']
# ['Position: Goal low left', 'Accurate']
# ['Goal', 'Right foot', 'Opportunity', 'Position: Goal center right', 'Accurate']
# ['Goal', 'Position: Goal center right', 'Not accurate']
# ['Right foot', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Position: Goal low center', 'Accurate']
# ['Counter attack', 'Right foot', 'Opportunity', 'Position: Goal low left', 'Accurate']
# ['Position: Goal low left', 'Accurate']
# ['Goal', 'Right foot', 'Opportunity', 'Position: Goal low left', 'Accurate']
# ['Goal', 'Position: Goal low left', 'Not accurate']
# ['Right foot', 'Direct', 'Opportunity', 'Position: Goal high left', 'Accurate']
# ['Position: Goal high left', 'Accurate']
# ['Right foot', 'Opportunity', 'Position: Goal center right', 'Accurate']
# ['Position: Goal center right', 'Accurate']
# ['Counter attack', 'Right foot', 'Opportunity', 'Position: Goal low left', 'Accurate']
# ['Position: Goal low left', 'Accurate']
# ['Goal', 'Counter attack', 'Right foot', 'Opportunity', 'Position: Goal high center', 'Accurate']
# ['Goal', 'Position: Goal high center', 'Not accurate']
# ['Right foot', 'Opportunity', 'Position: Goal high center', 'Accurate']
# ['Position: Goal high center', 'Accurate']
# ['Goal', 'Counter attack', 'Right foot', 'Opportunity', 'Position: Goal center right', 'Accurate']
# ['Goal', 'Position: Goal center right', 'Not accurate']
# ['Left foot', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Position: Goal low center', 'Accurate']
# ['Goal', 'Right foot', 'Opportunity', 'Position: Goal center left', 'Accurate']
# ['Goal', 'Position: Goal center left', 'Not accurate']
# ['Right foot', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Position: Goal low center', 'Accurate']
# ['Left foot', 'Direct', 'Opportunity', 'Position: Goal center right', 'Accurate']
# ['Position: Goal center right', 'Accurate']
# ['Head/body', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Position: Goal low center', 'Accurate']
# ['Goal', 'Right foot', 'Position: Goal low right', 'Accurate']
# ['Goal', 'Position: Goal low right', 'Not accurate']
# ['Right foot', 'Interception', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Position: Goal low center', 'Accurate']
# ['Goal', 'Right foot', 'Opportunity', 'Position: Goal low right', 'Accurate']
# ['Goal', 'Position: Goal low right', 'Not accurate']
# ['Right foot', 'Direct', 'Opportunity', 'Position: Goal high left', 'Accurate']
# ['Position: Goal high left', 'Accurate']
# ['Right foot', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Position: Goal low center', 'Accurate']
# ['Right foot', 'Opportunity', 'Position: Goal high left', 'Accurate']
# ['Position: Goal high left', 'Accurate']
# ['Goal', 'Right foot', 'Opportunity', 'Position: Goal high left', 'Accurate']
# ['Goal', 'Position: Goal high left', 'Not accurate']
# ['Head/body', 'Opportunity', 'Position: Goal high center', 'Accurate']
# ['Position: Goal high center', 'Accurate']
# ['Goal', 'Right foot', 'Position: Goal center', 'Accurate']
# ['Goal', 'Position: Goal center', 'Not accurate']
# ['Left foot', 'Opportunity', 'Position: Goal center', 'Accurate']
# ['Position: Goal center', 'Accurate']
# ['Goal', 'Left foot', 'Opportunity', 'Position: Goal center right', 'Accurate']
# ['Goal', 'Position: Goal center right', 'Not accurate']
# ['Goal', 'Right foot', 'Opportunity', 'Position: Goal high right', 'Accurate']
# ['Goal', 'Position: Goal high right', 'Not accurate']
# ['Goal', 'Head/body', 'Opportunity', 'Position: Goal high center', 'Accurate']
# ['Goal', 'Position: Goal high center', 'Not accurate']
# ['Left foot', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Position: Goal low center', 'Accurate']
# ['Right foot', 'Opportunity', 'Position: Goal center left', 'Accurate']
# ['Position: Goal center left', 'Accurate']
# ['Head/body', 'Opportunity', 'Position: Goal center', 'Accurate']
# ['Position: Goal center', 'Accurate']
# ['Head/body', 'Opportunity', 'Position: Goal center', 'Accurate']
# ['Position: Goal center', 'Accurate']
# ['Right foot', 'Opportunity', 'Position: Goal low right', 'Accurate']
# ['Position: Goal low right', 'Accurate']
# ['Head/body', 'Opportunity', 'Position: Goal center', 'Accurate']
# ['Position: Goal center', 'Accurate']
# ['Right foot', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Position: Goal low center', 'Accurate']
# ['Goal', 'Left foot', 'Direct', 'Opportunity', 'Position: Goal high right', 'Accurate']
# ['Goal', 'Position: Goal high right', 'Not accurate']
# ['Right foot', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Position: Goal low center', 'Accurate']
# ['Right foot', 'Opportunity', 'Position: Goal low left', 'Accurate']
# ['Position: Goal low left', 'Accurate']
# ['Right foot', 'Opportunity', 'Position: Goal high center', 'Accurate']
# ['Position: Goal high center', 'Accurate']
# ['Right foot', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Position: Goal low center', 'Accurate']
# ['Left foot', 'Opportunity', 'Position: Goal low left', 'Accurate']
# ['Position: Goal low left', 'Accurate']
# ['Head/body', 'Opportunity', 'Position: Goal center', 'Accurate']
# ['Position: Goal center', 'Accurate']
# ['Right foot', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Position: Goal low center', 'Accurate']
# ['Right foot', 'Opportunity', 'Position: Goal low right', 'Accurate']
# ['Position: Goal low right', 'Accurate']
# ['Goal', 'Right foot', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Goal', 'Position: Goal low center', 'Not accurate']
# ['Goal', 'Counter attack', 'Left foot', 'Opportunity', 'Position: Goal center left', 'Accurate']
# ['Goal', 'Position: Goal center left', 'Not accurate']
# ['Head/body', 'Opportunity', 'Position: Goal center right', 'Accurate']
# ['Position: Goal center right', 'Accurate']
# ['Goal', 'Head/body', 'Opportunity', 'Position: Goal high center', 'Accurate']
# ['Goal', 'Position: Goal high center', 'Not accurate']
# ['Right foot', 'Opportunity', 'Position: Goal low left', 'Accurate']
# ['Position: Goal low left', 'Accurate']
# ['Right foot', 'Opportunity', 'Position: Goal center', 'Accurate']
# ['Position: Goal center', 'Accurate']
# ['Goal', 'Left foot', 'Opportunity', 'Position: Goal center right', 'Accurate']
# ['Goal', 'Position: Goal center right', 'Not accurate']
# ['Right foot', 'Opportunity', 'Position: Goal center right', 'Accurate']
# ['Position: Goal center right', 'Accurate']
# ['Right foot', 'Opportunity', 'Position: Goal low right', 'Accurate']
# ['Position: Goal low right', 'Accurate']
# ['Goal', 'Left foot', 'Opportunity', 'Position: Goal low right', 'Accurate']
# ['Goal', 'Position: Goal low right', 'Not accurate']
# ['Left foot', 'Opportunity', 'Position: Goal center', 'Accurate']
# ['Position: Goal center', 'Accurate']
# ['Goal', 'Right foot', 'Opportunity', 'Position: Goal center', 'Accurate']
# ['Goal', 'Position: Goal center', 'Not accurate']
# ['Counter attack', 'Left foot', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Position: Goal low center', 'Accurate']
# ['Head/body', 'Opportunity', 'Position: Goal center', 'Accurate']
# ['Position: Goal center', 'Accurate']
# ['Head/body', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Position: Goal low center', 'Accurate']
# ['Goal', 'Head/body', 'Opportunity', 'Position: Goal center left', 'Accurate']
# ['Goal', 'Position: Goal center left', 'Not accurate']
# ['Left foot', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Position: Goal low center', 'Accurate']
# ['Right foot', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Position: Goal low center', 'Accurate']
# ['Left foot', 'Opportunity', 'Position: Goal center left', 'Accurate']
# ['Position: Goal center left', 'Accurate']
# ['Head/body', 'Opportunity', 'Position: Goal low left', 'Accurate']
# ['Position: Goal low left', 'Accurate']
# ['Left foot', 'Opportunity', 'Position: Goal low right', 'Accurate']
# ['Position: Goal low right', 'Accurate']
# ['Left foot', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Position: Goal low center', 'Accurate']
# ['Goal', 'Right foot', 'Opportunity', 'Position: Goal center', 'Accurate']
# ['Goal', 'Position: Goal center', 'Not accurate']
# ['Right foot', 'Opportunity', 'Position: Goal center', 'Accurate']
# ['Position: Goal center', 'Accurate']
# ['Goal', 'Head/body', 'Opportunity', 'Position: Goal center', 'Accurate']
# ['Goal', 'Position: Goal center', 'Not accurate']
# ['Counter attack', 'Right foot', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Position: Goal low center', 'Accurate']
# ['Goal', 'Right foot', 'Opportunity', 'Position: Goal low right', 'Accurate']
# ['Goal', 'Position: Goal low right', 'Not accurate']
# ['Left foot', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Position: Goal low center', 'Accurate']
# ['Right foot', 'Opportunity', 'Position: Goal center left', 'Accurate']
# ['Position: Goal center left', 'Accurate']
# ['Head/body', 'Opportunity', 'Position: Goal center left', 'Accurate']
# ['Position: Goal center left', 'Accurate']
# ['Right foot', 'Opportunity', 'Position: Goal center', 'Accurate']
# ['Position: Goal center', 'Accurate']
# ['Left foot', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Position: Goal low center', 'Accurate']
# ['Left foot', 'Opportunity', 'Position: Goal center', 'Accurate']
# ['Position: Goal center', 'Accurate']
# ['Right foot', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Position: Goal low center', 'Accurate']
# ['Goal', 'Counter attack', 'Right foot', 'Opportunity', 'Position: Goal low left', 'Accurate']
# ['Goal', 'Position: Goal low left', 'Not accurate']
# ['Right foot', 'Direct', 'Opportunity', 'Position: Goal high right', 'Accurate']
# ['Position: Goal high right', 'Accurate']
# ['Left foot', 'Opportunity', 'Position: Goal center left', 'Accurate']
# ['Position: Goal center left', 'Accurate']
# ['Left foot', 'Opportunity', 'Position: Goal low left', 'Accurate']
# ['Position: Goal low left', 'Accurate']
# ['Right foot', 'Opportunity', 'Position: Goal center left', 'Accurate']
# ['Position: Goal center left', 'Accurate']
# ['Left foot', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Position: Goal low center', 'Accurate']
# ['Left foot', 'Opportunity', 'Position: Goal low left', 'Accurate']
# ['Position: Goal low left', 'Accurate']
# ['Right foot', 'Opportunity', 'Position: Goal low left', 'Accurate']
# ['Position: Goal low left', 'Accurate']
# ['Head/body', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Position: Goal low center', 'Accurate']
# ['Goal', 'Right foot', 'Position: Goal low right', 'Accurate']
# ['Goal', 'Position: Goal low right', 'Not accurate']
# ['Counter attack', 'Right foot', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Position: Goal low center', 'Accurate']
# ['Goal', 'Counter attack', 'Right foot', 'Opportunity', 'Position: Goal center left', 'Accurate']
# ['Goal', 'Position: Goal center left', 'Not accurate']
# ['Right foot', 'Opportunity', 'Position: Goal center left', 'Accurate']
# ['Position: Goal center left', 'Accurate']
# ['Head/body', 'Opportunity', 'Position: Goal low left', 'Accurate']
# ['Position: Goal low left', 'Accurate']
# ['Goal', 'Left foot', 'Opportunity', 'Position: Goal low left', 'Accurate']
# ['Goal', 'Position: Goal low left', 'Not accurate']
# ['Left foot', 'Opportunity', 'Position: Goal low right', 'Accurate']
# ['Position: Goal low right', 'Accurate']
# ['Left foot', 'Opportunity', 'Position: Goal low left', 'Accurate']
# ['Position: Goal low left', 'Accurate']
# ['Head/body', 'Opportunity', 'Position: Goal high center', 'Accurate']
# ['Position: Goal high center', 'Accurate']
# ['Right foot', 'Opportunity', 'Position: Goal low right', 'Accurate']
# ['Position: Goal low right', 'Accurate']
# ['Goal', 'Right foot', 'Indirect', 'Opportunity', 'Position: Goal center right', 'Accurate']
# ['Goal', 'Position: Goal center right', 'Not accurate']
# ['Head/body', 'Opportunity', 'Position: Goal high center', 'Accurate']
# ['Position: Goal high center', 'Accurate']
# ['Goal', 'Left foot', 'Position: Goal center', 'Accurate']
# ['Goal', 'Position: Goal center', 'Not accurate']
# ['Right foot', 'Opportunity', 'Position: Goal high center', 'Accurate']
# ['Position: Goal high center', 'Accurate']
# ['Counter attack', 'Right foot', 'Opportunity', 'Position: Goal low left', 'Accurate']
# ['Position: Goal low left', 'Accurate']
# ['Left foot', 'Opportunity', 'Position: Goal low right', 'Accurate']
# ['Position: Goal low right', 'Accurate']
# ['Right foot', 'Opportunity', 'Position: Goal center', 'Accurate']
# ['Position: Goal center', 'Accurate']
# ['Left foot', 'Opportunity', 'Position: Goal high left', 'Accurate']
# ['Position: Goal high left', 'Accurate']
# ['Goal', 'Counter attack', 'Right foot', 'Opportunity', 'Position: Goal low left', 'Accurate']
# ['Goal', 'Position: Goal low left', 'Not accurate']
# ['Left foot', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Position: Goal low center', 'Accurate']
# ['Goal', 'Left foot', 'Opportunity', 'Position: Goal center left', 'Accurate']
# ['Goal', 'Position: Goal center left', 'Not accurate']
# ['Head/body', 'Opportunity', 'Position: Goal high right', 'Accurate']
# ['Position: Goal high right', 'Accurate']
# ['Right foot', 'Direct', 'Opportunity', 'Position: Goal center', 'Accurate']
# ['Position: Goal center', 'Accurate']
# ['Right foot', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Position: Goal low center', 'Accurate']
# ['Right foot', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Position: Goal low center', 'Accurate']
# ['Head/body', 'Opportunity', 'Position: Goal center left', 'Accurate']
# ['Position: Goal center left', 'Accurate']
# ['Head/body', 'Opportunity', 'Position: Goal high center', 'Accurate']
# ['Position: Goal high center', 'Accurate']
# ['Right foot', 'Opportunity', 'Position: Goal low left', 'Accurate']
# ['Position: Goal low left', 'Accurate']
# ['Right foot', 'Opportunity', 'Position: Goal center right', 'Accurate']
# ['Position: Goal center right', 'Accurate']
# ['Goal', 'Left foot', 'Opportunity', 'Position: Goal high right', 'Accurate']
# ['Goal', 'Position: Goal high right', 'Not accurate']
# ['Goal', 'Counter attack', 'Left foot', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Goal', 'Position: Goal low center', 'Not accurate']
# ['Right foot', 'Opportunity', 'Position: Goal center left', 'Accurate']
# ['Position: Goal center left', 'Accurate']
# ['Right foot', 'Direct', 'Opportunity', 'Position: Goal high center', 'Accurate']
# ['Position: Goal high center', 'Accurate']
# ['Right foot', 'Opportunity', 'Position: Goal high center', 'Accurate']
# ['Position: Goal high center', 'Accurate']
# ['Right foot', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Position: Goal low center', 'Accurate']
# ['Goal', 'Left foot', 'Opportunity', 'Position: Goal center', 'Accurate']
# ['Goal', 'Position: Goal center', 'Not accurate']
# ['Head/body', 'Opportunity', 'Position: Goal center left', 'Accurate']
# ['Position: Goal center left', 'Accurate']
# ['Goal', 'Right foot', 'Position: Goal high left', 'Accurate']
# ['Goal', 'Position: Goal high left', 'Not accurate']
# ['Left foot', 'Opportunity', 'Position: Goal center left', 'Accurate']
# ['Position: Goal center left', 'Accurate']
# ['Right foot', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Position: Goal low center', 'Accurate']
# ['Counter attack', 'Right foot', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Position: Goal low center', 'Accurate']
# ['Counter attack', 'Right foot', 'Opportunity', 'Position: Goal high right', 'Accurate']
# ['Position: Goal high right', 'Accurate']
# ['Right foot', 'Opportunity', 'Position: Goal center right', 'Accurate']
# ['Position: Goal center right', 'Accurate']
# ['Goal', 'Right foot', 'Opportunity', 'Position: Goal center left', 'Accurate']
# ['Goal', 'Position: Goal center left', 'Not accurate']
# ['Right foot', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Position: Goal low center', 'Accurate']
# ['Goal', 'Head/body', 'Opportunity', 'Position: Goal center right', 'Accurate']
# ['Goal', 'Position: Goal center right', 'Not accurate']
# ['Right foot', 'Opportunity', 'Position: Goal high right', 'Accurate']
# ['Position: Goal high right', 'Accurate']
# ['Goal', 'Counter attack', 'Left foot', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Goal', 'Position: Goal low center', 'Not accurate']
# ['Right foot', 'Direct', 'Opportunity', 'Position: Goal low left', 'Accurate']
# ['Position: Goal low left', 'Accurate']
# ['Right foot', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Position: Goal low center', 'Accurate']
# ['Head/body', 'Position: Goal high left', 'Accurate']
# ['Head/body', 'Opportunity', 'Position: Goal high center', 'Accurate']
# ['Position: Goal high center', 'Accurate']
# ['Goal', 'Right foot', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Goal', 'Position: Goal low center', 'Not accurate']
# ['Right foot', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Position: Goal low center', 'Accurate']
# ['Head/body', 'Opportunity', 'Position: Goal center right', 'Accurate']
# ['Position: Goal center right', 'Accurate']
# ['Goal', 'Right foot', 'Position: Goal low left', 'Accurate']
# ['Goal', 'Position: Goal low left', 'Not accurate']
# ['Head/body', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Position: Goal low center', 'Accurate']
# ['Goal', 'Head/body', 'Opportunity', 'Position: Goal center left', 'Accurate']
# ['Goal', 'Position: Goal center left', 'Not accurate']
# ['Left foot', 'Opportunity', 'Position: Goal low right', 'Accurate']
# ['Position: Goal low right', 'Accurate']
# ['Goal', 'Right foot', 'Position: Goal low left', 'Accurate']
# ['Goal', 'Position: Goal low left', 'Not accurate']
# ['Counter attack', 'Left foot', 'Opportunity', 'Position: Goal low right', 'Accurate']
# ['Position: Goal low right', 'Accurate']
# ['Right foot', 'Opportunity', 'Position: Goal low left', 'Accurate']
# ['Position: Goal low left', 'Accurate']
# ['Goal', 'Counter attack', 'Left foot', 'Opportunity', 'Position: Goal low right', 'Accurate']
# ['Goal', 'Position: Goal low right', 'Not accurate']
# ['Goal', 'Head/body', 'Opportunity', 'Position: Goal center right', 'Accurate']
# ['Goal', 'Position: Goal center right', 'Not accurate']
# ['Right foot', 'Opportunity', 'Position: Goal center', 'Accurate']
# ['Position: Goal center', 'Accurate']
# ['Right foot', 'Opportunity', 'Position: Goal high center', 'Accurate']
# ['Position: Goal high center', 'Accurate']
# ['Goal', 'Right foot', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Goal', 'Position: Goal low center', 'Not accurate']
# ['Left foot', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Position: Goal low center', 'Accurate']
# ['Goal', 'Left foot', 'Opportunity', 'Position: Goal center', 'Accurate']
# ['Goal', 'Position: Goal center', 'Not accurate']
# ['Left foot', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Position: Goal low center', 'Accurate']
# ['Left foot', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Position: Goal low center', 'Accurate']
# ['Right foot', 'Opportunity', 'Position: Goal center', 'Accurate']
# ['Position: Goal center', 'Accurate']
# ['Left foot', 'Opportunity', 'Position: Goal center', 'Accurate']
# ['Position: Goal center', 'Accurate']
# ['Goal', 'Left foot', 'Opportunity', 'Position: Goal low right', 'Accurate']
# ['Goal', 'Position: Goal low right', 'Not accurate']
# ['Goal', 'Right foot', 'Opportunity', 'Position: Goal low left', 'Accurate']
# ['Goal', 'Position: Goal low left', 'Not accurate']
# ['Goal', 'Head/body', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Goal', 'Position: Goal low center', 'Not accurate']
# ['Goal', 'Right foot', 'Position: Goal center left', 'Accurate']
# ['Goal', 'Position: Goal center left', 'Not accurate']
# ['Goal', 'Right foot', 'Opportunity', 'Position: Goal high right', 'Accurate']
# ['Goal', 'Position: Goal high right', 'Not accurate']
# ['Head/body', 'Opportunity', 'Position: Goal center', 'Accurate']
# ['Position: Goal center', 'Accurate']
# ['Goal', 'Head/body', 'Opportunity', 'Position: Goal high left', 'Accurate']
# ['Goal', 'Position: Goal high left', 'Not accurate']
# ['Goal', 'Right foot', 'Position: Goal center left', 'Accurate']
# ['Goal', 'Position: Goal center left', 'Not accurate']
# ['Goal', 'Right foot', 'Interception', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Goal', 'Position: Goal low center', 'Not accurate']
# ['Goal', 'Right foot', 'Opportunity', 'Position: Goal low right', 'Accurate']
# ['Goal', 'Position: Goal low right', 'Not accurate']
# ['Right foot', 'Opportunity', 'Position: Goal high center', 'Accurate']
# ['Position: Goal high center', 'Accurate']
# ['Goal', 'Left foot', 'Opportunity', 'Position: Goal high left', 'Accurate']
# ['Goal', 'Position: Goal high left', 'Not accurate']
# ['Right foot', 'Opportunity', 'Position: Goal low right', 'Accurate']
# ['Position: Goal low right', 'Accurate']
# ['Right foot', 'Opportunity', 'Position: Goal center left', 'Accurate']
# ['Position: Goal center left', 'Accurate']
# ['Head/body', 'Opportunity', 'Position: Goal low left', 'Accurate']
# ['Position: Goal low left', 'Accurate']
# ['Right foot', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Position: Goal low center', 'Accurate']
# ['Right foot', 'Opportunity', 'Position: Goal low left', 'Accurate']
# ['Position: Goal low left', 'Accurate']
# ['Right foot', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Position: Goal low center', 'Accurate']
# ['Goal', 'Right foot', 'Opportunity', 'Position: Goal center', 'Accurate']
# ['Goal', 'Position: Goal center', 'Not accurate']
# ['Right foot', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Position: Goal low center', 'Accurate']
# ['Counter attack', 'Right foot', 'Opportunity', 'Position: Goal low right', 'Accurate']
# ['Position: Goal low right', 'Accurate']
# ['Right foot', 'Opportunity', 'Position: Goal high center', 'Accurate']
# ['Position: Goal high center', 'Accurate']
# ['Goal', 'Right foot', 'Opportunity', 'Position: Goal center', 'Accurate']
# ['Goal', 'Position: Goal center', 'Not accurate']
# ['Left foot', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Position: Goal low center', 'Accurate']
# ['Right foot', 'Direct', 'Opportunity', 'Position: Goal center', 'Accurate']
# ['Position: Goal center', 'Accurate']
# ['Right foot', 'Direct', 'Opportunity', 'Position: Goal high right', 'Accurate']
# ['Position: Goal high right', 'Accurate']
# ['Goal', 'Right foot', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Goal', 'Position: Goal low center', 'Not accurate']
# ['Head/body', 'Opportunity', 'Position: Goal high right', 'Accurate']
# ['Position: Goal high right', 'Accurate']
# ['Left foot', 'Opportunity', 'Position: Goal center', 'Accurate']
# ['Position: Goal center', 'Accurate']
# ['Left foot', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Position: Goal low center', 'Accurate']
# ['Goal', 'Head/body', 'Opportunity', 'Position: Goal center right', 'Accurate']
# ['Goal', 'Position: Goal center right', 'Not accurate']
# ['Left foot', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Position: Goal low center', 'Accurate']
# ['Goal', 'Right foot', 'Position: Goal low center', 'Accurate']
# ['Goal', 'Position: Goal low center', 'Not accurate']
# ['Left foot', 'Opportunity', 'Position: Goal center right', 'Accurate']
# ['Position: Goal center right', 'Accurate']
# ['Right foot', 'Opportunity', 'Position: Goal center', 'Accurate']
# ['Position: Goal center', 'Accurate']
# ['Goal', 'Left foot', 'Direct', 'Opportunity', 'Position: Goal low right', 'Accurate']
# ['Goal', 'Position: Goal low right', 'Not accurate']
# ['Left foot', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Position: Goal low center', 'Accurate']
# ['Counter attack', 'Right foot', 'Opportunity', 'Position: Goal center right', 'Accurate']
# ['Position: Goal center right', 'Accurate']
# ['Goal', 'Head/body', 'Opportunity', 'Position: Goal center right', 'Accurate']
# ['Goal', 'Position: Goal center right', 'Not accurate']
# ['Goal', 'Head/body', 'Opportunity', 'Position: Goal center', 'Accurate']
# ['Goal', 'Position: Goal center', 'Not accurate']
# ['Left foot', 'Opportunity', 'Position: Goal center', 'Accurate']
# ['Position: Goal center', 'Accurate']
# ['Goal', 'Right foot', 'Opportunity', 'Position: Goal low left', 'Accurate']
# ['Goal', 'Position: Goal low left', 'Not accurate']
# ['Goal', 'Right foot', 'Opportunity', 'Position: Goal low right', 'Accurate']
# ['Goal', 'Position: Goal low right', 'Not accurate']
# ['Right foot', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Position: Goal low center', 'Accurate']
# ['Right foot', 'Opportunity', 'Position: Goal high center', 'Accurate']
# ['Position: Goal high center', 'Accurate']
# ['Right foot', 'Opportunity', 'Position: Goal center left', 'Accurate']
# ['Position: Goal center left', 'Accurate']
# ['Goal', 'Right foot', 'Opportunity', 'Position: Goal low left', 'Accurate']
# ['Goal', 'Position: Goal low left', 'Not accurate']
# ['Right foot', 'Opportunity', 'Position: Goal center', 'Accurate']
# ['Position: Goal center', 'Accurate']
# ['Right foot', 'Opportunity', 'Position: Goal center right', 'Accurate']
# ['Position: Goal center right', 'Accurate']
# ['Goal', 'Right foot', 'Opportunity', 'Position: Goal low right', 'Accurate']
# ['Goal', 'Position: Goal low right', 'Not accurate']
# ['Left foot', 'Opportunity', 'Position: Goal center', 'Accurate']
# ['Position: Goal center', 'Accurate']
# ['Head/body', 'Opportunity', 'Position: Goal center left', 'Accurate']
# ['Position: Goal center left', 'Accurate']
# ['Left foot', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Position: Goal low center', 'Accurate']
# ['Goal', 'Right foot', 'Opportunity', 'Position: Goal high right', 'Accurate']
# ['Goal', 'Position: Goal high right', 'Not accurate']
# ['Goal', 'Left foot', 'Opportunity', 'Position: Goal center right', 'Accurate']
# ['Goal', 'Position: Goal center right', 'Not accurate']
# ['Right foot', 'Opportunity', 'Position: Goal low left', 'Accurate']
# ['Position: Goal low left', 'Accurate']
# ['Left foot', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Position: Goal low center', 'Accurate']
# ['Head/body', 'Opportunity', 'Position: Goal center left', 'Accurate']
# ['Position: Goal center left', 'Accurate']
# ['Right foot', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Position: Goal low center', 'Accurate']
# ['Goal', 'Right foot', 'Opportunity', 'Position: Goal center right', 'Accurate']
# ['Goal', 'Position: Goal center right', 'Not accurate']
# ['Left foot', 'Direct', 'Opportunity', 'Position: Goal low left', 'Accurate']
# ['Position: Goal low left', 'Accurate']
# ['Right foot', 'Opportunity', 'Position: Goal center', 'Accurate']
# ['Position: Goal center', 'Accurate']
# ['Left foot', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Position: Goal low center', 'Accurate']
# ['Goal', 'Head/body', 'Opportunity', 'Position: Goal high center', 'Accurate']
# ['Goal', 'Position: Goal high center', 'Not accurate']
# ['Right foot', 'Opportunity', 'Position: Goal center', 'Accurate']
# ['Position: Goal center', 'Accurate']
# ['Right foot', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Position: Goal low center', 'Accurate']
# ['Goal', 'Head/body', 'Opportunity', 'Position: Goal center right', 'Accurate']
# ['Goal', 'Position: Goal center right', 'Not accurate']
# ['Right foot', 'Direct', 'Opportunity', 'Position: Goal low right', 'Accurate']
# ['Position: Goal low right', 'Accurate']
# ['Goal', 'Head/body', 'Opportunity', 'Position: Goal center', 'Accurate']
# ['Goal', 'Position: Goal center', 'Not accurate']
# ['Goal', 'Right foot', 'Opportunity', 'Position: Goal center right', 'Accurate']
# ['Goal', 'Position: Goal center right', 'Not accurate']
# ['Right foot', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Position: Goal low center', 'Accurate']
# ['Right foot', 'Opportunity', 'Position: Goal center', 'Accurate']
# ['Position: Goal center', 'Accurate']
# ['Goal', 'Left foot', 'Position: Goal low center', 'Accurate']
# ['Goal', 'Position: Goal low center', 'Not accurate']
# ['Goal', 'Left foot', 'Opportunity', 'Position: Goal center right', 'Accurate']
# ['Goal', 'Position: Goal center right', 'Not accurate']
# ['Goal', 'Left foot', 'Interception', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Goal', 'Position: Goal low center', 'Not accurate']
# ['Goal', 'Right foot', 'Opportunity', 'Position: Goal high left', 'Accurate']
# ['Goal', 'Position: Goal high left', 'Not accurate']
# ['Goal', 'Left foot', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Goal', 'Position: Goal low center', 'Not accurate']
# ['Goal', 'Right foot', 'Opportunity', 'Position: Goal low left', 'Accurate']
# ['Goal', 'Position: Goal low left', 'Not accurate']
# ['Right foot', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Position: Goal low center', 'Accurate']
# ['Goal', 'Head/body', 'Opportunity', 'Position: Goal low left', 'Accurate']
# ['Goal', 'Position: Goal low left', 'Not accurate']
# ['Goal', 'Right foot', 'Position: Goal low right', 'Accurate']
# ['Goal', 'Position: Goal low right', 'Not accurate']
# ['Right foot', 'Opportunity', 'Position: Goal low right', 'Accurate']
# ['Position: Goal low right', 'Accurate']
# ['Head/body', 'Opportunity', 'Position: Goal center right', 'Accurate']
# ['Counter attack', 'Position: Goal center right', 'Accurate']
# ['Right foot', 'Opportunity', 'Position: Goal center right', 'Accurate']
# ['Position: Goal center right', 'Accurate']
# ['Right foot', 'Opportunity', 'Position: Goal low left', 'Accurate']
# ['Position: Goal low left', 'Accurate']
# ['Left foot', 'Opportunity', 'Position: Goal low left', 'Accurate']
# ['Position: Goal low left', 'Accurate']
# ['Left foot', 'Opportunity', 'Position: Goal center', 'Accurate']
# ['Position: Goal center', 'Accurate']
# ['Head/body', 'Opportunity', 'Position: Goal center right', 'Accurate']
# ['Position: Goal center right', 'Accurate']
# ['Right foot', 'Opportunity', 'Position: Goal center right', 'Accurate']
# ['Position: Goal center right', 'Accurate']
# ['Left foot', 'Opportunity', 'Position: Goal low left', 'Accurate']
# ['Position: Goal low left', 'Accurate']
# ['Goal', 'Right foot', 'Position: Goal center', 'Accurate']
# ['Goal', 'Position: Goal center', 'Not accurate']
# ['Goal', 'Right foot', 'Position: Goal low left', 'Accurate']
# ['Goal', 'Position: Goal low left', 'Not accurate']
# ['Goal', 'Right foot', 'Position: Goal low left', 'Accurate']
# ['Goal', 'Position: Goal low left', 'Not accurate']
# ['Goal', 'Right foot', 'Position: Goal center right', 'Accurate']
# ['Goal', 'Position: Goal center right', 'Not accurate']
# ['Right foot', 'Position: Goal center', 'Not accurate']
# ['Position: Goal center', 'Accurate']
# ['Goal', 'Right foot', 'Position: Goal low center', 'Accurate']
# ['Goal', 'Position: Goal low center', 'Not accurate']
# ['Goal', 'Right foot', 'Position: Goal center left', 'Accurate']
# ['Goal', 'Position: Goal center left', 'Not accurate']
# ['Goal', 'Left foot', 'Position: Goal low center', 'Accurate']
# ['Goal', 'Position: Goal low center', 'Not accurate']
# ['Left foot', 'Position: Goal center', 'Not accurate']
# ['Position: Goal center', 'Accurate']
# ['Goal', 'Left foot', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Goal', 'Position: Goal low center', 'Not accurate']
# ['Goal', 'Right foot', 'Opportunity', 'Position: Goal center left', 'Accurate']
# ['Goal', 'Position: Goal center left', 'Not accurate']
# ['Right foot', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Position: Goal low center', 'Accurate']
# ['Counter attack', 'Right foot', 'Opportunity', 'Position: Goal center', 'Accurate']
# ['Position: Goal center', 'Accurate']
# ['Left foot', 'Opportunity', 'Position: Goal low left', 'Accurate']
# ['Position: Goal low left', 'Accurate']
# ['Right foot', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Position: Goal low center', 'Accurate']
# ['Left foot', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Position: Goal low center', 'Accurate']
# ['Head/body', 'Opportunity', 'Position: Goal center', 'Accurate']
# ['Position: Goal center', 'Accurate']
# ['Right foot', 'Position: Goal low right', 'Not accurate']
# ['Position: Goal low right', 'Accurate']
# ['Right foot', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Position: Goal low center', 'Accurate']
# ['Right foot', 'Position: Goal low left', 'Not accurate']
# ['Position: Goal low left', 'Accurate']
# ['Right foot', 'Position: Goal low center', 'Not accurate']
# ['Position: Goal low center', 'Accurate']
# ['Goal', 'Right foot', 'Position: Goal high right', 'Accurate']
# ['Goal', 'Position: Goal high right', 'Not accurate']
# ['Goal', 'Right foot', 'Position: Goal low left', 'Accurate']
# ['Goal', 'Position: Goal low left', 'Not accurate']
# ['Goal', 'Right foot', 'Position: Goal low left', 'Accurate']
# ['Goal', 'Position: Goal low left', 'Not accurate']
# ['Goal', 'Right foot', 'Position: Goal low center', 'Accurate']
# ['Goal', 'Position: Goal low center', 'Not accurate']
# ['Right foot', 'Position: Goal center left', 'Not accurate']
# ['Position: Goal center left', 'Accurate']
# ['Left foot', 'Position: Goal low left', 'Not accurate']
# ['Position: Goal low left', 'Accurate']
# ['Right foot', 'Position: Goal low center', 'Not accurate']
# ['Position: Goal low center', 'Accurate']
# ['Goal', 'Right foot', 'Position: Goal low left', 'Accurate']
# ['Goal', 'Position: Goal low left', 'Not accurate']
# ['Right foot', 'Opportunity', 'Position: Goal center', 'Accurate']
# ['Position: Goal center', 'Accurate']
# ['Right foot', 'Opportunity', 'Position: Goal center', 'Accurate']
# ['Position: Goal center', 'Accurate']
# ['Left foot', 'Opportunity', 'Position: Goal center left', 'Accurate']
# ['Position: Goal center left', 'Accurate']
# ['Right foot', 'Opportunity', 'Position: Goal center', 'Accurate']
# ['Position: Goal center', 'Accurate']
# ['Goal', 'Right foot', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Goal', 'Position: Goal low center', 'Not accurate']
# ['Right foot', 'Opportunity', 'Position: Goal center right', 'Accurate']
# ['Position: Goal center right', 'Accurate']
# ['Left foot', 'Opportunity', 'Position: Goal high center', 'Accurate']
# ['Position: Goal high center', 'Accurate']
# ['Right foot', 'Opportunity', 'Position: Goal high center', 'Accurate']
# ['Position: Goal high center', 'Accurate']
# ['Left foot', 'Opportunity', 'Position: Goal low right', 'Accurate']
# ['Position: Goal low right', 'Accurate']
# ['Counter attack', 'Right foot', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Position: Goal low center', 'Accurate']
# ['Goal', 'Right foot', 'Opportunity', 'Position: Goal low right', 'Accurate']
# ['Goal', 'Position: Goal low right', 'Not accurate']
# ['Left foot', 'Opportunity', 'Position: Goal center', 'Accurate']
# ['Position: Goal center', 'Accurate']
# ['Head/body', 'Opportunity', 'Position: Goal high right', 'Accurate']
# ['Position: Goal high right', 'Accurate']
# ['Goal', 'Counter attack', 'Right foot', 'Opportunity', 'Position: Goal low left', 'Accurate']
# ['Goal', 'Position: Goal low left', 'Not accurate']
# ['Goal', 'Right foot', 'Opportunity', 'Position: Goal center right', 'Accurate']
# ['Goal', 'Position: Goal center right', 'Not accurate']
# ['Goal', 'Head/body', 'Opportunity', 'Position: Goal center right', 'Accurate']
# ['Goal', 'Position: Goal center right', 'Not accurate']
# ['Goal', 'Head/body', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Goal', 'Position: Goal low center', 'Not accurate']
# ['Head/body', 'Opportunity', 'Position: Goal center left', 'Accurate']
# ['Position: Goal center left', 'Accurate']
# ['Head/body', 'Opportunity', 'Position: Goal high center', 'Accurate']
# ['Position: Goal high center', 'Accurate']
# ['Left foot', 'Opportunity', 'Position: Goal center', 'Accurate']
# ['Position: Goal center', 'Accurate']
# ['Left foot', 'Direct', 'Opportunity', 'Position: Goal center left', 'Accurate']
# ['Position: Goal center left', 'Accurate']
# ['Goal', 'Counter attack', 'Left foot', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Goal', 'Position: Goal low center', 'Not accurate']
# ['Right foot', 'Opportunity', 'Position: Goal center', 'Accurate']
# ['Position: Goal center', 'Accurate']
# ['Left foot', 'Opportunity', 'Position: Goal low left', 'Accurate']
# ['Position: Goal low left', 'Accurate']
# ['Left foot', 'Direct', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Position: Goal low center', 'Accurate']
# ['Goal', 'Right foot', 'Opportunity', 'Position: Goal center', 'Accurate']
# ['Goal', 'Position: Goal center', 'Not accurate']
# ['Right foot', 'Opportunity', 'Position: Goal center', 'Accurate']
# ['Position: Goal center', 'Accurate']
# ['Head/body', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Position: Goal low center', 'Accurate']
# ['Right foot', 'Direct', 'Opportunity', 'Position: Goal center', 'Accurate']
# ['Position: Goal center', 'Accurate']
# ['Right foot', 'Direct', 'Opportunity', 'Position: Goal high right', 'Accurate']
# ['Position: Goal high right', 'Accurate']
# ['Left foot', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Position: Goal low center', 'Accurate']
# ['Goal', 'Right foot', 'Position: Goal center', 'Accurate']
# ['Goal', 'Position: Goal center', 'Not accurate']
# ['Right foot', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Position: Goal low center', 'Accurate']
# ['Right foot', 'Opportunity', 'Position: Goal center right', 'Accurate']
# ['Position: Goal center right', 'Accurate']
# ['Goal', 'Head/body', 'Opportunity', 'Position: Goal center left', 'Accurate']
# ['Goal', 'Position: Goal center left', 'Not accurate']
# ['Goal', 'Right foot', 'Position: Goal center', 'Accurate']
# ['Goal', 'Position: Goal center', 'Not accurate']
# ['Goal', 'Right foot', 'Position: Goal low left', 'Accurate']
# ['Goal', 'Position: Goal low left', 'Not accurate']
# ['Goal', 'Right foot', 'Position: Goal center left', 'Accurate']
# ['Goal', 'Position: Goal center left', 'Not accurate']
# ['Goal', 'Right foot', 'Position: Goal low left', 'Accurate']
# ['Goal', 'Position: Goal low left', 'Not accurate']
# ['Goal', 'Right foot', 'Position: Goal low right', 'Accurate']
# ['Goal', 'Position: Goal low right', 'Not accurate']
# ['Right foot', 'Position: Goal low right', 'Not accurate']
# ['Position: Goal low right', 'Accurate']
# ['Goal', 'Right foot', 'Position: Goal high left', 'Accurate']
# ['Goal', 'Position: Goal high left', 'Not accurate']
# ['Right foot', 'Position: Goal center', 'Not accurate']
# ['Position: Goal center', 'Accurate']
# ['Goal', 'Right foot', 'Position: Goal low left', 'Accurate']
# ['Goal', 'Position: Goal low left', 'Not accurate']
# ['Right foot', 'Opportunity', 'Position: Goal low right', 'Accurate']
# ['Position: Goal low right', 'Accurate']
# ['Goal', 'Head/body', 'Opportunity', 'Position: Goal low left', 'Accurate']
# ['Goal', 'Position: Goal low left', 'Not accurate']
# ['Left foot', 'Opportunity', 'Position: Goal center', 'Accurate']
# ['Position: Goal center', 'Accurate']
# ['Head/body', 'Opportunity', 'Position: Goal center left', 'Accurate']
# ['Position: Goal center left', 'Accurate']
# ['Goal', 'Counter attack', 'Left foot', 'Opportunity', 'Position: Goal center', 'Accurate']
# ['Goal', 'Position: Goal center', 'Not accurate']
# ['Right foot', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Position: Goal low center', 'Accurate']
# ['Left foot', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Position: Goal low center', 'Accurate']
# ['Goal', 'Counter attack', 'Right foot', 'Opportunity', 'Position: Goal center left', 'Accurate']
# ['Goal', 'Position: Goal center left', 'Not accurate']
# ['Right foot', 'Opportunity', 'Position: Goal center right', 'Accurate']
# ['Position: Goal center right', 'Accurate']
# ['Right foot', 'Direct', 'Opportunity', 'Position: Goal high center', 'Accurate']
# ['Position: Goal high center', 'Accurate']
# ['Right foot', 'Opportunity', 'Position: Goal low left', 'Accurate']
# ['Position: Goal low left', 'Accurate']
# ['Right foot', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Position: Goal low center', 'Accurate']
# ['Right foot', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Position: Goal low center', 'Accurate']
# ['Left foot', 'Opportunity', 'Position: Goal center left', 'Accurate']
# ['Position: Goal center left', 'Accurate']
# ['Counter attack', 'Right foot', 'Opportunity', 'Position: Goal center', 'Accurate']
# ['Position: Goal center', 'Accurate']
# ['Goal', 'Head/body', 'Opportunity', 'Position: Goal low right', 'Accurate']
# ['Goal', 'Position: Goal low right', 'Not accurate']
# ['Right foot', 'Opportunity', 'Position: Goal high right', 'Accurate']
# ['Position: Goal high right', 'Accurate']
# ['Goal', 'Left foot', 'Opportunity', 'Position: Goal high left', 'Accurate']
# ['Goal', 'Position: Goal high left', 'Not accurate']
# ['Goal', 'Head/body', 'Opportunity', 'Position: Goal low right', 'Accurate']
# ['Goal', 'Position: Goal low right', 'Not accurate']
# ['Right foot', 'Opportunity', 'Position: Goal low left', 'Accurate']
# ['Position: Goal low left', 'Accurate']
# ['Head/body', 'Opportunity', 'Position: Goal center', 'Accurate']
# ['Position: Goal center', 'Accurate']
# ['Right foot', 'Opportunity', 'Position: Goal center right', 'Accurate']
# ['Position: Goal center right', 'Accurate']
# ['Goal', 'Head/body', 'Opportunity', 'Position: Goal center right', 'Accurate']
# ['Goal', 'Position: Goal center right', 'Not accurate']
# ['Right foot', 'Opportunity', 'Position: Goal center right', 'Accurate']
# ['Position: Goal center right', 'Accurate']
# ['Goal', 'Head/body', 'Opportunity', 'Position: Goal center left', 'Accurate']
# ['Goal', 'Position: Goal center left', 'Not accurate']
# ['Right foot', 'Opportunity', 'Position: Goal low left', 'Accurate']
# ['Position: Goal low left', 'Accurate']
# ['Right foot', 'Position: Goal center left', 'Not accurate']
# ['Position: Goal center left', 'Accurate']
# ['Goal', 'Right foot', 'Position: Goal high right', 'Accurate']
# ['Goal', 'Position: Goal high right', 'Not accurate']
# ['Goal', 'Right foot', 'Position: Goal low right', 'Accurate']
# ['Goal', 'Position: Goal low right', 'Not accurate']
# ['Right foot', 'Position: Goal low right', 'Not accurate']
# ['Position: Goal low right', 'Accurate']
# ['Goal', 'Right foot', 'Position: Goal low left', 'Accurate']
# ['Goal', 'Position: Goal low left', 'Not accurate']
# ['Goal', 'Right foot', 'Position: Goal low left', 'Accurate']
# ['Goal', 'Position: Goal low left', 'Not accurate']
# ['Goal', 'Right foot', 'Position: Goal high left', 'Accurate']
# ['Goal', 'Position: Goal high left', 'Not accurate']
# ['Goal', 'Right foot', 'Position: Goal low left', 'Accurate']
# ['Goal', 'Position: Goal low left', 'Not accurate']
# ['Goal', 'Right foot', 'Position: Goal low left', 'Accurate']
# ['Goal', 'Position: Goal low left', 'Not accurate']
# ['Goal', 'Head/body', 'Opportunity', 'Position: Goal low left', 'Accurate']
# ['Goal', 'Position: Goal low left', 'Not accurate']
# ['Head/body', 'Opportunity', 'Position: Goal center right', 'Accurate']
# ['Position: Goal center right', 'Accurate']
# ['Goal', 'Head/body', 'Opportunity', 'Position: Goal high center', 'Accurate']
# ['Goal', 'Position: Goal high center', 'Not accurate']
# ['Right foot', 'Opportunity', 'Position: Goal low left', 'Accurate']
# ['Position: Goal low left', 'Accurate']
# ['Left foot', 'Opportunity', 'Position: Goal high center', 'Accurate']
# ['Position: Goal high center', 'Accurate']
# ['Left foot', 'Opportunity', 'Position: Goal center', 'Accurate']
# ['Position: Goal center', 'Accurate']
# ['Left foot', 'Opportunity', 'Position: Goal center left', 'Accurate']
# ['Position: Goal center left', 'Accurate']
# ['Right foot', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Position: Goal low center', 'Accurate']
# ['Goal', 'Head/body', 'Opportunity', 'Position: Goal center right', 'Accurate']
# ['Goal', 'Position: Goal center right', 'Not accurate']
# ['Right foot', 'Opportunity', 'Position: Goal center right', 'Accurate']
# ['Position: Goal center right', 'Accurate']
# ['Right foot', 'Opportunity', 'Position: Goal low left', 'Accurate']
# ['Position: Goal low left', 'Accurate']
# ['Left foot', 'Opportunity', 'Position: Goal low right', 'Accurate']
# ['Position: Goal low right', 'Accurate']
# ['Goal', 'Right foot', 'Direct', 'Opportunity', 'Position: Goal high right', 'Accurate']
# ['Goal', 'Position: Goal high right', 'Not accurate']
# ['Left foot', 'Opportunity', 'Position: Goal center', 'Accurate']
# ['Position: Goal center', 'Accurate']
# ['Goal', 'Left foot', 'Opportunity', 'Position: Goal low left', 'Accurate']
# ['Goal', 'Position: Goal low left', 'Not accurate']
# ['Right foot', 'Opportunity', 'Position: Goal center left', 'Accurate']
# ['Position: Goal center left', 'Accurate']
# ['Right foot', 'Opportunity', 'Position: Goal center right', 'Accurate']
# ['Position: Goal center right', 'Accurate']
# ['Head/body', 'Opportunity', 'Position: Goal high left', 'Accurate']
# ['Position: Goal high left', 'Accurate']
# ['Right foot', 'Opportunity', 'Position: Goal center left', 'Accurate']
# ['Position: Goal center left', 'Accurate']
# ['Goal', 'Left foot', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Goal', 'Position: Goal low center', 'Not accurate']
# ['Right foot', 'Opportunity', 'Position: Goal high center', 'Accurate']
# ['Position: Goal high center', 'Accurate']
# ['Goal', 'Right foot', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Goal', 'Position: Goal low center', 'Not accurate']
# ['Right foot', 'Opportunity', 'Position: Goal center', 'Accurate']
# ['Position: Goal center', 'Accurate']
# ['Right foot', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Position: Goal low center', 'Accurate']
# ['Head/body', 'Opportunity', 'Position: Goal high center', 'Accurate']
# ['Position: Goal high center', 'Accurate']
# ['Right foot', 'Opportunity', 'Position: Goal low left', 'Accurate']
# ['Position: Goal low left', 'Accurate']
# ['Right foot', 'Opportunity', 'Position: Goal low center', 'Accurate']
# ['Position: Goal low center', 'Accurate']
# ['Right foot', 'Opportunity', 'Position: Goal center left', 'Accurate']
# ['Position: Goal center left', 'Accurate']
# ['Right foot', 'Opportunity', 'Position: Goal low left', 'Accurate']
# ['Position: Goal low left', 'Accurate']
# ['Goal', 'Right foot', 'Opportunity', 'Position: Goal low left', 'Accurate']
# ['Goal', 'Position: Goal low left', 'Not accurate']
# ['Goal', 'Left foot', 'Opportunity', 'Position: Goal center right', 'Accurate']
# ['Goal', 'Position: Goal center right', 'Not accurate']
# ['Goal', 'Left foot', 'Position: Goal low left', 'Accurate']
# ['Goal', 'Position: Goal low left', 'Not accurate']
# ['Left foot', 'Opportunity', 'Position: Goal center', 'Accurate']
# ['Position: Goal center', 'Accurate']
# ['Left foot', 'Opportunity', 'Position: Goal high left', 'Accurate']
# ['Position: Goal high left', 'Accurate']
# ['Counter attack', 'Right foot', 'Opportunity', 'Position: Goal low right', 'Accurate']
# ['Position: Goal low right', 'Accurate']
# ['Goal', 'Left foot', 'Opportunity', 'Position: Goal center left', 'Accurate']
# ['Goal', 'Position: Goal center left', 'Not accurate']
# ['Goal', 'Right foot', 'Opportunity', 'Position: Goal low left', 'Accurate']
# ['Goal', 'Position: Goal low left', 'Not accurate']
# ['Goal', 'Right foot', 'Opportunity', 'Position: Goal low left', 'Accurate']
# ['Goal', 'Position: Goal low left', 'Not accurate']
# ['Left foot', 'Opportunity', 'Position: Goal center left', 'Accurate']
# ['Position: Goal center left', 'Accurate']

# %%
df["tags"] = df["tags"].apply(ast.literal_eval)

# %%
# find unique values in a list

uniquetags = set()

for taglist in df["tags"]:
    for tag in taglist:
        uniquetags.add(tag)
print(uniquetags)
# Out:
# {'Lost', 'Take on left', 'Position: Out low left', 'Not accurate', 'Position: Out high left', 'Neutral', 'Position: Post center left', 'Won', 'Accurate', 'Take on right', 'Opportunity', 'Position: Out high center', 'Position: Post low left', 'Position: Out low right', 'Position: Goal center right', 'Position: Goal low center', 'Position: Out center left', 'Position: Goal center', 'Second yellow card', 'Position: Out high right', 'Red card', 'Through', 'Anticipation', 'High', 'Sliding tackle', 'Goal', 'Position: Post center right', 'Position: Goal high center', 'Head/body', 'Counter attack', 'Left foot', 'Position: Goal high right', 'Interception', 'Free space left', 'Position: Goal high left', 'Position: Out center right', 'Fairplay', 'Position: Goal center left', 'Blocked', 'Position: Post low right', 'Right foot', 'Position: Post high left', 'Missed ball', 'Position: Goal low left', 'Feint', 'Position: Goal low right', 'Yellow card', 'Anticipated', 'Own goal', 'Assist', 'Direct', 'Dangerous ball lost', 'Indirect', 'Position: Post high right', 'Position: Post high center', 'Key pass', 'Free space right'}

# %%
# alternatively as a single line loop

uniquetags = set([tag for taglist in df["tags"] for tag in taglist])
print(uniquetags)
# Out:
# {'Lost', 'Take on left', 'Position: Out low left', 'Not accurate', 'Position: Out high left', 'Neutral', 'Position: Post center left', 'Won', 'Accurate', 'Take on right', 'Opportunity', 'Position: Out high center', 'Position: Post low left', 'Position: Out low right', 'Position: Goal center right', 'Position: Goal low center', 'Position: Out center left', 'Position: Goal center', 'Second yellow card', 'Position: Out high right', 'Red card', 'Through', 'Anticipation', 'High', 'Sliding tackle', 'Goal', 'Position: Post center right', 'Position: Goal high center', 'Head/body', 'Counter attack', 'Left foot', 'Position: Goal high right', 'Interception', 'Free space left', 'Position: Goal high left', 'Position: Out center right', 'Fairplay', 'Position: Goal center left', 'Blocked', 'Position: Post low right', 'Right foot', 'Position: Post high left', 'Missed ball', 'Position: Goal low left', 'Feint', 'Position: Goal low right', 'Yellow card', 'Anticipated', 'Own goal', 'Assist', 'Direct', 'Dangerous ball lost', 'Indirect', 'Position: Post high right', 'Position: Post high center', 'Key pass', 'Free space right'}

# %%
df["pass"] = (df["eventName"] == "Pass").astype(int)
df["shot"] = (df["eventName"] == "Shot").astype(int)
df["goal"] = ((df["eventName"] == "Shot") & (df["tags"].apply(lambda x: "Goal" in x))).astype(int)
df["acc_pass"] = ((df["eventName"] == "Pass") & (df["tags"].apply(lambda x: "Accurate" in x))).astype(int)
df.head(1)
# Out:
#    eventId subEventName        tags                     playerId  \
# 0        8  Simple pass  [Accurate]  Mohammad Ibrahim Al Sahlawi
#
#                         matchId eventName        teamId matchPeriod  eventSec  \
# 0  Russia - Saudi Arabia, 5 - 0      Pass  Saudi Arabia          1H  1.656214
#
#     subEventId         id  x1  y1    x2    y2  pass  shot  goal  acc_pass
# 0  Simple pass  258612104  50  50  35.0  53.0     1     0     0         1

# %%
from math import dist
def get_golden_shot(row:pd.Series):
    is_shot = row["eventName"] == "Shot"
    x_len = 120
    y_len = 75
    x1 = (row["x1"] / 100) * x_len
    y1 = (row["y1"] /100) * y_len
    x2 = (100 / 100) * x_len
    y2 = ((100/2)/100) * y_len
    d = dist([x1,y1],[x2,y2])
    if is_shot and d <= 18:
        return 1
    else:
        return 0

df["golden_shot"] = df.apply(get_golden_shot, axis=1)
df.head(1)
# Out:
#    eventId subEventName        tags                     playerId  \
# 0        8  Simple pass  [Accurate]  Mohammad Ibrahim Al Sahlawi
#
#                         matchId eventName        teamId matchPeriod  eventSec  \
# 0  Russia - Saudi Arabia, 5 - 0      Pass  Saudi Arabia          1H  1.656214
#
#     subEventId         id  x1  y1    x2    y2  pass  shot  goal  acc_pass  \
# 0  Simple pass  258612104  50  50  35.0  53.0     1     0     0         1
#
#    golden_shot
# 0            0

# %%
grp = df.groupby(["matchId", "teamId"]).agg(
    shots = ("shot", "sum"),
    passes = ("pass", "sum"),
    goals = ("goal", "sum"),
    golden_shots = ("golden_shot", "sum"),
    acc_passes = ("acc_pass", "sum")
).reset_index()

grp["perc_acc_pass"] = grp["acc_passes"] / grp["passes"]
grp["perc_gold_shot"] = grp["golden_shots"] / grp["shots"]
grp
# Out:
#                            matchId        teamId  shots  passes  goals  \
# 0       Argentina - Croatia, 0 - 3     Argentina     10     476      0
# 1       Argentina - Croatia, 0 - 3       Croatia     13     334      3
# 2       Argentina - Iceland, 1 - 1     Argentina     22     744      1
# 3       Argentina - Iceland, 1 - 1       Iceland      8     183      1
# 4          Australia - Peru, 0 - 2     Australia     11     512      0
# ..                             ...           ...    ...     ...    ...
# 123      Uruguay - Portugal, 2 - 1       Uruguay      6     238      2
# 124        Uruguay - Russia, 3 - 0        Russia      3     327      0
# 125        Uruguay - Russia, 3 - 0       Uruguay     12     466      1
# 126  Uruguay - Saudi Arabia, 1 - 0  Saudi Arabia      7     553      0
# 127  Uruguay - Saudi Arabia, 1 - 0       Uruguay     13     473      1
#
#      golden_shots  acc_passes  perc_acc_pass  perc_gold_shot
# 0               7         393       0.825630        0.700000
# 1               5         261       0.781437        0.384615
# 2               6         675       0.907258        0.272727
# 3               3         141       0.770492        0.375000
# 4               7         446       0.871094        0.636364
# ..            ...         ...            ...             ...
# 123             1         185       0.777311        0.166667
# 124             0         271       0.828746        0.000000
# 125             5         405       0.869099        0.416667
# 126             2         482       0.871609        0.285714
# 127             8         410       0.866808        0.615385
#
# [128 rows x 9 columns]

# %%
import seaborn as sns , matplotlib.pyplot as plt
def viz_corr(x:str, y:str):
    plt.figure(figsize=(5,3))
    r,p = stats.pearsonr(grp[x], grp[y])
    r2 = r**2
    reg = sns.regplot(data=grp, x=x, y=y, line_kws={"color":"red"})
    text = f"""r={r:.4f}
p={p:.4f}
r2={r2:.4f}"""
    reg.text(
        0.1,
        0.7,
        text,
        transform=reg.transAxes,
        bbox={"boxstyle":"round,pad=0.5", "fc":"white"}
    )
    plt.show()

# %%
grp.corr(numeric_only=True)
# Out:
#                    shots    passes     goals  golden_shots  acc_passes  \
# shots           1.000000  0.564229  0.210675      0.785044    0.555309
# passes          0.564229  1.000000  0.120015      0.500424    0.995563
# goals           0.210675  0.120015  1.000000      0.220095    0.125879
# golden_shots    0.785044  0.500424  0.220095      1.000000    0.496650
# acc_passes      0.555309  0.995563  0.125879      0.496650    1.000000
# perc_acc_pass   0.392210  0.741263  0.162325      0.357474    0.788865
# perc_gold_shot  0.036478  0.097462  0.147073      0.565483    0.101464
#
#                 perc_acc_pass  perc_gold_shot
# shots                0.392210        0.036478
# passes               0.741263        0.097462
# goals                0.162325        0.147073
# golden_shots         0.357474        0.565483
# acc_passes           0.788865        0.101464
# perc_acc_pass        1.000000        0.098569
# perc_gold_shot       0.098569        1.000000

# %%
viz_corr("acc_passes","shots")

# %%
viz_corr("acc_passes", "golden_shots")

# %%
viz_corr("perc_gold_shot", "goals")

# %%
viz_corr("golden_shots", "goals")
